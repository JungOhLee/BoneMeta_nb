# %%
import os
import SimpleITK as sitk
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd

import nibabel
from monai.transforms import Resize

import time

# %%
import sys
sys.path.insert(1, '/workspace')
from utils.utils import *

# %%
from_dir = '/workspace/BoneMeta_all_128/preds/bonemeta_fn_0_3D_Unet_Res_lv6_PS128_All128_model_epoch3000/numpy'
to_dir = '/workspace/BoneMeta_nnUnet/1st_pred'
image_dir = '/workspace/BoneMeta_nnUnet/images'

os.makedirs(to_dir, exist_ok=True)

data_info_path = '/workspace/DataInfo/data_info.csv'


def get_label_path(file):
    return os.path.join(label_data_dir, file)

def get_image_path(file):
    return os.path.join(image_data_dir, file)

# %%
data_info = pd.read_csv(data_info_path, index_col=0)
data_info.tail()
# Out:
#                       case_id                 resolution         size[mm]  \
# 4333  000308_20190801_abdomen  [0.652344, 0.652344, 1.0]  [334, 334, 405]
# 4334  000308_20190801_abdomen  [0.652344, 0.652344, 1.0]  [334, 334, 405]
# 4335  000308_20190801_abdomen  [0.652344, 0.652344, 1.0]  [334, 334, 405]
# 4336    000376_20200114_chest  [0.578125, 0.578125, 1.0]  [296, 296, 317]
# 4337    000376_20200114_chest  [0.578125, 0.578125, 1.0]  [296, 296, 317]
#
#      volumeInfo_volumeOriginCoord        dimension  \
# 4333      (-171.01,-28.71,187.61)  [512, 512, 405]
# 4334      (-171.01,-28.71,187.61)  [512, 512, 405]
# 4335      (-171.01,-28.71,187.61)  [512, 512, 405]
# 4336      (-177.01,-13.70,950.18)  [512, 512, 317]
# 4337      (-177.01,-13.70,950.18)  [512, 512, 317]
#
#                                      calculatedFeatures           center  \
# 4333  {'TextureFeatureParameters': {'GLCMBins': 64, ...  [385, 324, 234]
# 4334  {'TextureFeatureParameters': {'GLCMBins': 64, ...  [379, 310, 305]
# 4335  {'FractalFeatureParameters': {'BoxCountingSlid...  [103, 331, 398]
# 4336  {'FractalFeatureParameters': {'BoxCountingSlid...   [43, 282, 242]
# 4337  {'FractalFeatureParameters': {'BoxCountingSlid...  [256, 242, 158]
#
#      resampled_center  hasPixelMask         maskFileNameNifti  \
# 4333  [251, 211, 234]         False                       NaN
# 4334  [247, 202, 305]         False                       NaN
# 4335   [67, 216, 398]          True  lesionAnnot3D-010.nii.gz
# 4336   [25, 163, 242]          True  lesionAnnot3D-001.nii.gz
# 4337  [148, 140, 158]          True  lesionAnnot3D-002.nii.gz
#
#                           maskFileNameSegmask                      maskPos  \
# 4333                                      NaN  (375,314,165)-(395,334,178)
# 4334                                      NaN   (370,301,92)-(388,319,108)
# 4335  lesionAnnot3D-010.512x512x405.psegmaskz      (93,321,0)-(113,341,15)
# 4336  lesionAnnot3D-001.512x512x317.psegmaskz      (24,250,60)-(62,313,89)
# 4337  lesionAnnot3D-002.512x512x317.psegmaskz       (0,85,0)-(511,399,317)
#
#                                                 maskVOI  \
# 4333  (73.6209,176.128,352.61)-(86.6678,189.175,365.61)
# 4334   (70.3592,167.647,279.61)-(82.1014,179.39,295.61)
# 4335  (-110.34,180.694,187.61)-(-97.2932,193.741,202...
# 4336  (-163.133,130.831,1010.18)-(-141.164,167.253,1...
# 4337  (-177.008,35.4406,950.18)-(118.414,216.972,126...
#
#                                  measureValue                     type  \
# 4333       0.0 [mm³]\r\n13.0 x 13.0 x 13 [mm]  ELesionAnnotType_ROI_3D
# 4334       0.0 [mm³]\r\n11.7 x 11.7 x 16 [mm]  ELesionAnnotType_ROI_3D
# 4335     798.8 [mm³]\r\n13.0 x 13.0 x 15 [mm]  ELesionAnnotType_ROI_3D
# 4336                             5014.4 [mm³]  ELesionAnnotType_ROI_3D
# 4337  1664.1 [cc]\r\n295.4 x 181.5 x 317 [mm]  ELesionAnnotType_ROI_3D
#
#                         annotation
# 4333         Left pelvic bone-1/25
# 4334         Left pelvic bone-1/25
# 4335    Right femur/metastasis/I/S
# 4336  Right 9th rib/metastasis/V/L
# 4337                          Bone

# %%
ct_info = data_info.loc[:,['case_id', 'resolution', 'size[mm]', 'dimension']]
ct_info.drop_duplicates(inplace=True)
ct_info.set_index('case_id',inplace=True)
print(ct_info.shape)
ct_info.head()
# Out:
# (310, 3)
#                                        resolution         size[mm]  \
# case_id
# 000251_20190703_chest   [0.560547, 0.560547, 1.0]  [287, 287, 297]
# 000356_20191024_chest   [0.621094, 0.621094, 1.0]  [318, 318, 322]
# 000350_20190927_chest   [0.589844, 0.589844, 1.0]  [302, 302, 327]
# 000397_20200214_chest   [0.613281, 0.613281, 1.0]  [314, 314, 348]
# BH005_20170701_abdomen  [0.646484, 0.646484, 1.0]  [331, 331, 471]
#
#                               dimension
# case_id
# 000251_20190703_chest   [512, 512, 297]
# 000356_20191024_chest   [512, 512, 322]
# 000350_20190927_chest   [512, 512, 327]
# 000397_20200214_chest   [512, 512, 348]
# BH005_20170701_abdomen  [512, 512, 471]

# %%
def str_to_crz_list(resolution):
    crz = resolution.strip('[]').split(', ')
    return [float(value) for value in crz]

# %%
def save_image(np_image, target_dir, file_name):
    np_image = np_image.astype(np.int16)
    np.save(os.path.join(target_dir, file_name), np_image)
    
def save_label(np_image, target_dir, file_name):
    np_image = (np_image>0).astype(np.uint8)
    np.save(os.path.join(target_dir, file_name), np_image)

# %%
def resample(np_image, dimension_str): 
    crz = str_to_crz_list(dimension_str)
    zrc_dim = [int(i) for i in crz[::-1]]
    resizer = Resize(zrc_dim)
    resized_image = resizer(np_image[np.newaxis,:]) # with channel
    return resized_image[0] # without channel

def resample_all_files_with_dim(file_dir, target_dir, resample_func, save_func):
    file_list = os.listdir(file_dir)
    for file in file_list:
        np_file = np.load(os.path.join(file_dir, file))
        dimension_str = ct_info.loc[file_to_case(file)].dimension
        resampled_image = resample_func(np_file, dimension_str)
        save_func(resampled_image, target_dir, file)

# %%
t = time.perf_counter()

resample_all_files_with_dim(from_dir, to_dir, resample, save_image)

elapsed_time = time.perf_counter() - t

print(f'''
consumed_time: {elapsed_time}s
''')
# Out:
# consumed_time: 540.490312772803s

# %%
# %debug
# Out:
# ERROR:root:No traceback has been produced, nothing to debug.

# %%
file_names = os.listdir(to_dir)
resampled_sizes = [np.load(os.path.join(to_dir, file)).shape for file in file_names]
image_sizes = [np.load(os.path.join(image_dir, file)).shape for file in file_names]

# %%
image_sizes == resampled_sizes
# Out:
# True
