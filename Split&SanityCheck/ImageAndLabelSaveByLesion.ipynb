# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import SimpleITK as sitk
import nibabel as nib
from monai.transforms import Resize
import time
import gc
import tracemalloc

from matplotlib import figure

# %%
IMG_BASE_DIR = '/workspace/BoneMeta_new'
LABEL_BASE_DIR = '/workspace/BoneMeta_raw_02'
SAVE_BASE_DIR = '/workspace'
IMG_FOLDER_NAME = 'images'
LABEL_FOLDER_NAME = 'label'

WINDOWS = [(500,200), (1200,400)]
DATA_INFO_PATH = '/workspace/DataInfo/data_info_20220310_VI.csv'

# %%
DATA_INFO = pd.read_csv(DATA_INFO_PATH)
DATA_INFO = DATA_INFO.sort_values(['Case', 'File Name'])
DATA_INFO.reset_index(drop=True, inplace=True)
DATA_INFO.set_index(['Case','File Name'], inplace=True)

IMG_DIR = os.path.join(IMG_BASE_DIR, IMG_FOLDER_NAME)
LABEL_DIR = os.path.join(LABEL_BASE_DIR, LABEL_FOLDER_NAME)

IMG_FILES = os.listdir(IMG_DIR)
LABEL_FILES = os.listdir(LABEL_DIR)

def get_img_path(file): 
    return os.path.join(IMG_DIR, file)

def get_label_path(case, file):
    return os.path.join(LABEL_DIR, case, file)

def case_to_file(case):
    return case+'.npy'

def file_to_case(file_name):
    return file_name.split('.')[0]

# %%
DATA_INFO.head()
# Out:
#                                                                                   Data  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz       test
#                                                    lesionAnnot3D-004.nii.gz       test
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz  train_add
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz       test
#                                                    lesionAnnot3D-002.nii.gz       test
#
#                                                                             Lesion Type  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz           S
#                                                    lesionAnnot3D-004.nii.gz           S
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz           L
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz           S
#                                                    lesionAnnot3D-002.nii.gz           S
#
#                                                                             Lesion Location  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz              C7
#                                                    lesionAnnot3D-004.nii.gz             T10
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz              L5
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            C7-1
#                                                    lesionAnnot3D-002.nii.gz            C7-2
#
#                                                                             I/V  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   I
#                                                    lesionAnnot3D-004.nii.gz   I
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz   V
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   V
#                                                    lesionAnnot3D-002.nii.gz   I
#
#                                                                              Lesion Size  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            0
#                                                    lesionAnnot3D-004.nii.gz            0
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz            0
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            0
#                                                    lesionAnnot3D-002.nii.gz            0
#
#                                                                              Background Size  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            13125
#                                                    lesionAnnot3D-004.nii.gz            14500
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz           198880
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            11136
#                                                    lesionAnnot3D-002.nii.gz             1820
#
#                                                                               Original Shape  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  [512, 512, 400]
#                                                    lesionAnnot3D-004.nii.gz  [512, 512, 400]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz  [512, 512, 145]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  [512, 512, 340]
#                                                    lesionAnnot3D-002.nii.gz  [512, 512, 340]
#
#                                                                             1mm Resized Shape  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   [376, 376, 376]
#                                                    lesionAnnot3D-004.nii.gz   [376, 376, 376]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz   [323, 323, 323]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   [378, 378, 378]
#                                                    lesionAnnot3D-002.nii.gz   [378, 378, 378]
#
#                                                                              Original Center  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   [265, 282, 33]
#                                                    lesionAnnot3D-004.nii.gz  [255, 321, 266]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz   [298, 298, 92]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz    [263, 307, 8]
#                                                    lesionAnnot3D-002.nii.gz   [278, 290, 19]
#
#                                                                             1mm Resized Center  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz     [195, 208, 33]
#                                                    lesionAnnot3D-004.nii.gz    [188, 236, 266]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz    [188, 188, 276]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz      [194, 227, 8]
#                                                    lesionAnnot3D-002.nii.gz     [205, 214, 19]
#
#                                                                              Pixel Size  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz        1144
#                                                    lesionAnnot3D-004.nii.gz        3449
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz       34062
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz        2299
#                                                    lesionAnnot3D-002.nii.gz         872
#
#                                                                                  Spine Shape  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  [256, 256, 400]
#                                                    lesionAnnot3D-004.nii.gz  [256, 256, 400]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz  [256, 256, 145]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  [256, 256, 340]
#                                                    lesionAnnot3D-002.nii.gz  [256, 256, 340]
#
#                                                                             Spine Resized Shape  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz       [48, 113, 33]
#                                                    lesionAnnot3D-004.nii.gz      [40, 142, 266]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz      [62, 107, 276]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz        [46, 132, 8]
#                                                    lesionAnnot3D-002.nii.gz       [57, 119, 19]
#
#                                                                                Spine Center  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz   [65, 154, 33]
#                                                    lesionAnnot3D-004.nii.gz  [55, 193, 266]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz   [98, 170, 92]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz    [63, 179, 8]
#                                                    lesionAnnot3D-002.nii.gz   [78, 162, 19]
#
#                                                                             Spine Resized Shape.1  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz         [48, 113, 33]
#                                                    lesionAnnot3D-004.nii.gz        [40, 142, 266]
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz        [62, 107, 276]
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz          [46, 132, 8]
#                                                    lesionAnnot3D-002.nii.gz         [57, 119, 19]
#
#                                                                              X Spacing  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz     0.7363
#                                                    lesionAnnot3D-004.nii.gz     0.7363
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz     0.6309
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz     0.7383
#                                                    lesionAnnot3D-002.nii.gz     0.7383
#
#                                                                              Y Spacing  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz     0.7363
#                                                    lesionAnnot3D-004.nii.gz     0.7363
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz     0.6309
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz     0.7383
#                                                    lesionAnnot3D-002.nii.gz     0.7383
#
#                                                                              Slice Interval  \
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            -1.0
#                                                    lesionAnnot3D-004.nii.gz            -1.0
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz            -3.0
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz            -1.0
#                                                    lesionAnnot3D-002.nii.gz            -1.0
#
#                                                                             Memo
# Case                                               File Name
# 000002_20180829_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  NaN
#                                                    lesionAnnot3D-004.nii.gz  NaN
# 000005_20181202_CT_Abdomen+Pelvis_Dynamic_(cont... lesionAnnot3D-001.nii.gz  NaN
# 000009_20180417_Chest_CT_(contrast)                lesionAnnot3D-001.nii.gz  NaN
#                                                    lesionAnnot3D-002.nii.gz  NaN

# %%
def get_image_file(filename):
    return np.load(get_img_path(filename))

def get_label_file(case, filename):
    label = nib.load(get_label_path(case, filename))
    label_npy = label.get_fdata().transpose((2,1,0))
    return label_npy.astype(np.uint8)

# %%
print(IMG_DIR, len(IMG_FILES))
# Out:
# /workspace/BoneMeta_new/images 402

# %%
# 케이스별 DICOM 읽기: case_name, base_dir -> npy
def dcm_to_numpy(case_name, base_dir):
  dicoms = sorted(glob.glob(f'{base_dir}/{case_name}/*'))
  dcm_reader = sitk.ImageSeriesReader()
  dcm_reader.SetFileNames(dicoms)
  img_arr = sitk.GetArrayFromImage(dcm_reader.Execute())
  return img_arr

def slice_img(img, offset, end, interval):
  if end is None:
    end = len(img)
  else: 
    if end > len(img): 
      end = len(img)
    if end <= offset:
      end = offset + 1
  return img[offset:end:interval]

def show_numpy_img(np_img, offset=0, end=None, interval=5, title=''): 
  sliced_img = slice_img(np_img, offset, end, interval)

  figsize_per_img = 3
  num_col = 5
  num_row = int(np.ceil(sliced_img.shape[0] / num_col))
  # fig, axs = plt.subplots(num_row, num_col, figsize = (figsize_per_img*num_col, figsize_per_img*num_row))
  plt.figure(figsize=(figsize_per_img*num_col, figsize_per_img*num_row))
  for i, img in enumerate(sliced_img):
    if i >= num_col*num_row:
      continue
    # axs[i].imshow(img)
    plt.subplot(num_row, num_col, i+1)
    plt.imshow(img, 'gray')
    # plt.title()
  plt.suptitle(title)
  plt.tight_layout()
  plt.show()

# npy image windowing 하기
def adjust_window(image, window):
    width = window[0]
    level = window[1]
    upper = level+width/2
    lower = level-width/2
    copied_image = image.copy()
    copied_image[copied_image<lower] = lower
    copied_image[copied_image>upper] = upper
    copied_image = copied_image-lower
    return (copied_image/(upper-lower)*255).round().astype(np.uint8)

# # 2nd version
# def adjust_window(image, window):
#     width = window[0]
#     level = window[1]
#     upper = level+width/2
#     lower = level-width/2
#     copied_image = image.clip(lower, upper)
#     copied_image = copied_image-lower
#     return (copied_image/(upper-lower)*255)

#npy image 정보 보여주기 
def show_img_info(np_img):
  print('Shape:', np_img.shape)
  print('DType:', np_img.dtype)
  print('Max:', np_img.max())
  print('Min:', np_img.min())
  print(np_img)

# %%
# label있는 부분만 저장
def save_img_and_lesion_label(np_img, label, case, lesion_filename, tag ='', interval = 2, figsize_per_image = 10):
  offset = 0
  end = None
  sliced_img = slice_img(np_img, offset, end, interval)
  sliced_label = slice_img(label, offset, end, interval)
  
  label_idx = sliced_label.any(axis=(1,2))
  sliced_img = sliced_img[label_idx]
  sliced_label = sliced_label[label_idx]

  num_row = len(sliced_img)
  num_col = 2

  save_dir = f'{SAVE_BASE_DIR}/image_check/{case}'
  os.makedirs(save_dir, exist_ok=True)

  for i in range(0, num_row):
    save_path = f'{save_dir}/{case[:30]}_{file_to_case(lesion_filename)}_{tag}_{i}.png'
    if os.path.exists(save_path): 
      continue;
    f = figure.Figure(figsize=(figsize_per_image*num_col, figsize_per_image))
    f.patch.set_facecolor('black')
    plt.subplot(1, num_col, 1)
    tissue_image = sliced_img[i]
    plt.imshow(tissue_image, 'gray')

    plt.subplot(1, num_col, 2)
    mask = sliced_label[i]
    label_on_tissue = sitk.LabelMapContourOverlay(sitk.Cast(sitk.GetImageFromArray(mask), sitk.sitkLabelUInt8), sitk.GetImageFromArray(tissue_image), opacity=0.7, contourThickness=[2,2], colormap=(0,255,0))
    plt.imshow(sitk.GetArrayFromImage(label_on_tissue), 'gray')

    plt.tight_layout()
    plt.savefig(save_path)
    
#     f.clf()
#   plt.show()
#     plt.close('all')
    plt.close(f)
    plt.clf()

# %% [markdown]
# Pseudocode
# ```
# DATA_INFO 기준으로 진행.
# for case in DATA_INFO
#   read img
#   iso_voxel img
#   for lesion in DATA_INFO, case
#     read label
#     iso_vosel label
#
#     join and save img and label
#      - axial sagittal
#      - (500,200), (1200,400)
#
# ```

# %%
WINDOWS = [(500,200), (1200,400)]
def resize(npy, resizer):
    return resizer(npy[np.newaxis,])[0,:]

# %%
def save_lesion_img_from_data_info(data_info):
    working_case = ''
    for i, (case, lesion_file) in enumerate(data_info.index.values):
        try:             
            if working_case != case:
                working_case = case
                img = get_image_file(case_to_file(case))

                xyz_string = DATA_INFO.loc[(case, lesion_file), 'Original Shape'][0]
                x_spacing = DATA_INFO.loc[(case, lesion_file), 'X Spacing'][0]
                y_spacing = DATA_INFO.loc[(case, lesion_file), 'Y Spacing'][0]
                z_spacing = abs(DATA_INFO.loc[(case, lesion_file), 'Slice Interval'][0])
                xyz = xyz_string[1:-1].split(', ')
                x,y,z = [int(i) for i in xyz]
                new_shape = [int(x * x_spacing), int(y * y_spacing), int(z * z_spacing)]
                resizer = Resize(new_shape)

                img = resize(img, resizer)

            label = get_label_file(case, lesion_file)
            label = resize(label, resizer)
            
            iv = DATA_INFO.loc[(case, lesion_file),'I/V'][0]
            slm_type = DATA_INFO.loc[(case, lesion_file),'Lesion Type'][0]
            
            for window in WINDOWS: 
                adj_image = adjust_window(img, window)
                save_img_and_lesion_label(adj_image, label, case, lesion_file, tag = 'Axial'+str(window)+f'_{iv}_{slm_type}')

                coronal_image = adj_image.transpose(1,0,2)
                coronal_label = label.transpose(1,0,2)
                save_img_and_lesion_label(coronal_image, coronal_label, case, lesion_file, tag = 'Cor'+str(window)+f'_{iv}_{slm_type}')

            gc.collect()
        except:
            print(case, lesion_file)
            continue;

# %%
class Timer():
    start = 0
    end = 0
    def start(self):
        self.start = time.perf_counter()
        
    def end(self):
        self.end = time.perf_counter()
        print(self.end - self.start)
        return(self.end - self.start)

# %%
from multiprocessing import Pool

timer = Timer()
timer.start()
num_process = 45
chunk_size = len(DATA_INFO) // num_process + 1

datainfo_list = [DATA_INFO.iloc[i*chunk_size: (i+1)*chunk_size] for i in range(num_process)]
with Pool(processes=num_process) as pool:
    
    pool.map(save_lesion_img_from_data_info, datainfo_list)
    pool.close() 
    pool.join()
timer.end()
# Out:
# <ipython-input-7-afb7fca23977>:48: size=32.1 MiB, count=2, average=16.1 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2447, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=127 KiB, count=1538, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.5 KiB, count=151, average=255 B
# memory_blocks= 2 size_kB= 32893.2763671875
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=46.1 MiB, count=2, average=23.0 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2430, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=127 KiB, count=1522, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.6 KiB, count=152, average=253 B
# memory_blocks= 2 size_kB= 47174.03515625
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=23.4 MiB, count=2, average=11.7 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2433, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=126 KiB, count=1526, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=36.8 KiB, count=147, average=256 B
# memory_blocks= 2 size_kB= 24009.1357421875
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=31.2 MiB, count=2, average=15.6 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2424, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1548, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.1 KiB, count=158, average=247 B
# memory_blocks= 2 size_kB= 31908.28125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=52.0 MiB, count=2, average=26.0 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2432, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1563, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.5 KiB, count=150, average=256 B
# memory_blocks= 2 size_kB= 53278.77734375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=42.7 MiB, count=2, average=21.4 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2421, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1554, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.4 KiB, count=169, average=245 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 43758.359375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=45.9 MiB, count=2, average=23.0 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2409, average=82 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1548, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.8 KiB, count=173, average=241 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 47002.609375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=28.9 MiB, count=2, average=14.4 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2425, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1544, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.0 KiB, count=157, average=248 B
# memory_blocks= 2 size_kB= 29562.08984375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=45.6 MiB, count=2, average=22.8 MiB
# <frozen importlib._bootstrap_external>:487: size=191 KiB, count=2400, average=82 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1565, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.2 KiB, count=166, average=248 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 46665.203125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=36.7 MiB, count=2, average=18.3 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2452, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1564, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=36.7 KiB, count=146, average=258 B
# memory_blocks= 2 size_kB= 37576.7216796875
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=21.3 MiB, count=2, average=10.6 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2454, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1553, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.7 KiB, count=153, average=252 B
# memory_blocks= 2 size_kB= 21763.1328125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=31.0 MiB, count=2, average=15.5 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2425, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1579, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.4 KiB, count=149, average=257 B
# memory_blocks= 2 size_kB= 31730.24609375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=38.8 MiB, count=2, average=19.4 MiB
# <frozen importlib._bootstrap_external>:487: size=195 KiB, count=2461, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=127 KiB, count=1538, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py:411: size=36.9 KiB, count=67, average=564 B
# memory_blocks= 2 size_kB= 39699.1484375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=61.1 MiB, count=2, average=30.6 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2452, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1547, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=36.6 KiB, count=145, average=259 B
# memory_blocks= 2 size_kB= 62567.65625
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=42.9 MiB, count=2, average=21.4 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2428, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=127 KiB, count=1521, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.8 KiB, count=154, average=251 B
# memory_blocks= 2 size_kB= 43918.953125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=56.3 MiB, count=2, average=28.1 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2443, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1548, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.5 KiB, count=163, average=242 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 57621.07421875
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=49.0 MiB, count=2, average=24.5 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2450, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1552, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.9 KiB, count=156, average=249 B
# memory_blocks= 2 size_kB= 50154.203125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=45.6 MiB, count=2, average=22.8 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2439, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1565, average=84 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.4 KiB, count=168, average=246 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# <ipython-input-7-afb7fca23977>:48: size=31.7 MiB, count=2, average=15.9 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2440, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1555, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.2 KiB, count=159, average=246 B
# memory_blocks= 2 size_kB= memory_blocks=32499.7197265625
# 2  File "<ipython-input-7-afb7fca23977>", line 48
# size_kB=    return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# 46706.8896484375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=46.3 MiB, count=2, average=23.1 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2422, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=127 KiB, count=1533, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.2 KiB, count=160, average=245 B
# memory_blocks= 2 size_kB= 47407.578125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=34.9 MiB, count=2, average=17.4 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2412, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1546, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.5 KiB, count=170, average=244 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 35700.078125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=31.7 MiB, count=2, average=15.8 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2444, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=129 KiB, count=1566, average=84 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.4 KiB, count=162, average=243 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 32416.390625
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=24.5 MiB, count=2, average=12.3 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2427, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1543, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.6 KiB, count=171, average=243 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 25100.078125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=66.4 MiB, count=2, average=33.2 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2426, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1555, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.7 KiB, count=172, average=242 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 68025.7109375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=45.1 MiB, count=2, average=22.6 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2417, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=130 KiB, count=1577, average=84 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.1 KiB, count=165, average=249 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 46216.953125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=44.6 MiB, count=2, average=22.3 MiB
# <frozen importlib._bootstrap_external>:487: size=211 KiB, count=2694, average=80 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=121 KiB, count=1451, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.8 KiB, count=174, average=240 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 45698.3203125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=27.4 MiB, count=2, average=13.7 MiB
# <frozen importlib._bootstrap_external>:487: size=194 KiB, count=2443, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=130 KiB, count=1573, average=84 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=37.8 KiB, count=155, average=250 B
# memory_blocks= 2 size_kB= 28047.4580078125
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=26.2 MiB, count=2, average=13.1 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2421, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1549, average=85 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.3 KiB, count=161, average=244 B
# memory_blocks= 2 size_kB= 26802.9169921875
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=39.7 MiB, count=2, average=19.9 MiB
# <frozen importlib._bootstrap_external>:487: size=192 KiB, count=2410, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=128 KiB, count=1548, average=85 B
# /usr/lib/python3.6/_weakrefset.py:84: size=38.5 KiB, count=164, average=241 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 40686.65234375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# <ipython-input-7-afb7fca23977>:48: size=60.5 MiB, count=2, average=30.2 MiB
# <frozen importlib._bootstrap_external>:487: size=193 KiB, count=2423, average=81 B
# /usr/lib/python3.6/multiprocessing/queues.py:337: size=131 KiB, count=1594, average=84 B
# /usr/lib/python3.6/_weakrefset.py:84: size=40.3 KiB, count=167, average=247 B
# /usr/local/lib/python3.6/dist-packages/matplotlib/transforms.py:201: size=38.4 KiB, count=8, average=4912 B
# memory_blocks= 2 size_kB= 61923.37109375
#   File "<ipython-input-7-afb7fca23977>", line 48
#     return (copied_image/(upper-lower)*255).round().astype(np.uint8)
# 000301_20190801_CT_Acute_Abdomen_(contrast) lesionAnnot3D-061.nii.gz
# BH109_20181210_Chest_CT_(contrast)_+_3D_(Breast_with_other_CT) lesionAnnot3D-002.nii.gz
# 000506_20201113_Chest_CT_(contrast) lesionAnnot3D-002.nii.gz
# 3258.382281505037
# 3258.382281505037
